# %%
import requests

# %%
url='https://data.epa.gov.tw/api/v2/aqx_p_02?api_key=e8dd42e6-9b8b-43f8-991e-b3dee723a52d&limit=1000&sort=datacreationdate%20desc&format=JSON'

# %%
resp=requests.get(url)
resp
# Out:
# <Response [200]>

# %% [markdown]
# ### 取得資料所在位置

# %%
datas=resp.json()['records']
datas
# Out:
# [{'site': '大城',
#   'county': '彰化縣',
#   'pm25': '',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '富貴角',
#   'county': '新北市',
#   'pm25': '11',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '麥寮',
#   'county': '雲林縣',
#   'pm25': '9',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '關山',
#   'county': '臺東縣',
#   'pm25': '18',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '馬公',
#   'county': '澎湖縣',
#   'pm25': '12',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '金門',
#   'county': '金門縣',
#   'pm25': '13',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '馬祖',
#   'county': '連江縣',
#   'pm25': '17',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '埔里',
#   'county': '南投縣',
#   'pm25': '15',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '復興',
#   'county': '高雄市',
#   'pm25': '11',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '永和',
#   'county': '新北市',
#   'pm25': '7',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '竹山',
#   'county': '南投縣',
#   'pm25': '12',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '中壢',
#   'county': '桃園市',
#   'pm25': '10',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '三重',
#   'county': '新北市',
#   'pm25': '9',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '冬山',
#   'county': '宜蘭縣',
#   'pm25': '18',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '宜蘭',
#   'county': '宜蘭縣',
#   'pm25': '12',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '陽明',
#   'county': '臺北市',
#   'pm25': '1',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '花蓮',
#   'county': '花蓮縣',
#   'pm25': '12',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '臺東',
#   'county': '臺東縣',
#   'pm25': '19',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '恆春',
#   'county': '屏東縣',
#   'pm25': '6',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '潮州',
#   'county': '屏東縣',
#   'pm25': '12',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '屏東',
#   'county': '屏東縣',
#   'pm25': '14',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '小港',
#   'county': '高雄市',
#   'pm25': '11',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '前鎮',
#   'county': '高雄市',
#   'pm25': '9',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '前金',
#   'county': '高雄市',
#   'pm25': '10',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '左營',
#   'county': '高雄市',
#   'pm25': '15',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '楠梓',
#   'county': '高雄市',
#   'pm25': '11',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '林園',
#   'county': '高雄市',
#   'pm25': '6',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '大寮',
#   'county': '高雄市',
#   'pm25': '12',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '鳳山',
#   'county': '高雄市',
#   'pm25': '12',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '仁武',
#   'county': '高雄市',
#   'pm25': '13',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '橋頭',
#   'county': '高雄市',
#   'pm25': '9',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '美濃',
#   'county': '高雄市',
#   'pm25': '14',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '臺南',
#   'county': '臺南市',
#   'pm25': '7',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '安南',
#   'county': '臺南市',
#   'pm25': '13',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '善化',
#   'county': '臺南市',
#   'pm25': '10',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '新營',
#   'county': '臺南市',
#   'pm25': '11',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '嘉義',
#   'county': '嘉義市',
#   'pm25': '10',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '臺西',
#   'county': '雲林縣',
#   'pm25': '15',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '朴子',
#   'county': '嘉義縣',
#   'pm25': '11',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '新港',
#   'county': '嘉義縣',
#   'pm25': '9',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '崙背',
#   'county': '雲林縣',
#   'pm25': '10',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '斗六',
#   'county': '雲林縣',
#   'pm25': '12',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '南投',
#   'county': '南投縣',
#   'pm25': '7',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '二林',
#   'county': '彰化縣',
#   'pm25': '13',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '線西',
#   'county': '彰化縣',
#   'pm25': '16',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '彰化',
#   'county': '彰化縣',
#   'pm25': '14',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '西屯',
#   'county': '臺中市',
#   'pm25': '14',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '忠明',
#   'county': '臺中市',
#   'pm25': '16',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '大里',
#   'county': '臺中市',
#   'pm25': '12',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '沙鹿',
#   'county': '臺中市',
#   'pm25': '14',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '豐原',
#   'county': '臺中市',
#   'pm25': '17',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '三義',
#   'county': '苗栗縣',
#   'pm25': '12',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '苗栗',
#   'county': '苗栗縣',
#   'pm25': '11',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '頭份',
#   'county': '苗栗縣',
#   'pm25': '10',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '新竹',
#   'county': '新竹市',
#   'pm25': '9',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '竹東',
#   'county': '新竹縣',
#   'pm25': '6',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '湖口',
#   'county': '新竹縣',
#   'pm25': '9',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '龍潭',
#   'county': '桃園市',
#   'pm25': '3',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '平鎮',
#   'county': '桃園市',
#   'pm25': '4',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '觀音',
#   'county': '桃園市',
#   'pm25': '9',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '大園',
#   'county': '桃園市',
#   'pm25': '6',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '桃園',
#   'county': '桃園市',
#   'pm25': '',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '大同',
#   'county': '臺北市',
#   'pm25': '12',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '松山',
#   'county': '臺北市',
#   'pm25': '7',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '古亭',
#   'county': '臺北市',
#   'pm25': '8',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '萬華',
#   'county': '臺北市',
#   'pm25': '7',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '中山',
#   'county': '臺北市',
#   'pm25': '11',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '士林',
#   'county': '臺北市',
#   'pm25': '16',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '淡水',
#   'county': '新北市',
#   'pm25': '7',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '林口',
#   'county': '新北市',
#   'pm25': '6',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '菜寮',
#   'county': '新北市',
#   'pm25': '10',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '新莊',
#   'county': '新北市',
#   'pm25': '8',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '板橋',
#   'county': '新北市',
#   'pm25': '10',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '土城',
#   'county': '新北市',
#   'pm25': '3',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '新店',
#   'county': '新北市',
#   'pm25': '9',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '萬里',
#   'county': '新北市',
#   'pm25': '12',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '汐止',
#   'county': '新北市',
#   'pm25': '13',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'},
#  {'site': '基隆',
#   'county': '基隆市',
#   'pm25': '',
#   'datacreationdate': '2023-04-19 16:00',
#   'itemunit': 'μg/m3'}]

# %%
len(datas)
# Out:
# 78

# %%
columns=list(datas[0].keys())
values=[]
for data in datas:
    values.append(list(data.values()))

columns,values
# Out:
# (['site', 'county', 'pm25', 'datacreationdate', 'itemunit'],
#  [['大城', '彰化縣', '', '2023-04-19 16:00', 'μg/m3'],
#   ['富貴角', '新北市', '11', '2023-04-19 16:00', 'μg/m3'],
#   ['麥寮', '雲林縣', '9', '2023-04-19 16:00', 'μg/m3'],
#   ['關山', '臺東縣', '18', '2023-04-19 16:00', 'μg/m3'],
#   ['馬公', '澎湖縣', '12', '2023-04-19 16:00', 'μg/m3'],
#   ['金門', '金門縣', '13', '2023-04-19 16:00', 'μg/m3'],
#   ['馬祖', '連江縣', '17', '2023-04-19 16:00', 'μg/m3'],
#   ['埔里', '南投縣', '15', '2023-04-19 16:00', 'μg/m3'],
#   ['復興', '高雄市', '11', '2023-04-19 16:00', 'μg/m3'],
#   ['永和', '新北市', '7', '2023-04-19 16:00', 'μg/m3'],
#   ['竹山', '南投縣', '12', '2023-04-19 16:00', 'μg/m3'],
#   ['中壢', '桃園市', '10', '2023-04-19 16:00', 'μg/m3'],
#   ['三重', '新北市', '9', '2023-04-19 16:00', 'μg/m3'],
#   ['冬山', '宜蘭縣', '18', '2023-04-19 16:00', 'μg/m3'],
#   ['宜蘭', '宜蘭縣', '12', '2023-04-19 16:00', 'μg/m3'],
#   ['陽明', '臺北市', '1', '2023-04-19 16:00', 'μg/m3'],
#   ['花蓮', '花蓮縣', '12', '2023-04-19 16:00', 'μg/m3'],
#   ['臺東', '臺東縣', '19', '2023-04-19 16:00', 'μg/m3'],
#   ['恆春', '屏東縣', '6', '2023-04-19 16:00', 'μg/m3'],
#   ['潮州', '屏東縣', '12', '2023-04-19 16:00', 'μg/m3'],
#   ['屏東', '屏東縣', '14', '2023-04-19 16:00', 'μg/m3'],
#   ['小港', '高雄市', '11', '2023-04-19 16:00', 'μg/m3'],
#   ['前鎮', '高雄市', '9', '2023-04-19 16:00', 'μg/m3'],
#   ['前金', '高雄市', '10', '2023-04-19 16:00', 'μg/m3'],
#   ['左營', '高雄市', '15', '2023-04-19 16:00', 'μg/m3'],
#   ['楠梓', '高雄市', '11', '2023-04-19 16:00', 'μg/m3'],
#   ['林園', '高雄市', '6', '2023-04-19 16:00', 'μg/m3'],
#   ['大寮', '高雄市', '12', '2023-04-19 16:00', 'μg/m3'],
#   ['鳳山', '高雄市', '12', '2023-04-19 16:00', 'μg/m3'],
#   ['仁武', '高雄市', '13', '2023-04-19 16:00', 'μg/m3'],
#   ['橋頭', '高雄市', '9', '2023-04-19 16:00', 'μg/m3'],
#   ['美濃', '高雄市', '14', '2023-04-19 16:00', 'μg/m3'],
#   ['臺南', '臺南市', '7', '2023-04-19 16:00', 'μg/m3'],
#   ['安南', '臺南市', '13', '2023-04-19 16:00', 'μg/m3'],
#   ['善化', '臺南市', '10', '2023-04-19 16:00', 'μg/m3'],
#   ['新營', '臺南市', '11', '2023-04-19 16:00', 'μg/m3'],
#   ['嘉義', '嘉義市', '10', '2023-04-19 16:00', 'μg/m3'],
#   ['臺西', '雲林縣', '15', '2023-04-19 16:00', 'μg/m3'],
#   ['朴子', '嘉義縣', '11', '2023-04-19 16:00', 'μg/m3'],
#   ['新港', '嘉義縣', '9', '2023-04-19 16:00', 'μg/m3'],
#   ['崙背', '雲林縣', '10', '2023-04-19 16:00', 'μg/m3'],
#   ['斗六', '雲林縣', '12', '2023-04-19 16:00', 'μg/m3'],
#   ['南投', '南投縣', '7', '2023-04-19 16:00', 'μg/m3'],
#   ['二林', '彰化縣', '13', '2023-04-19 16:00', 'μg/m3'],
#   ['線西', '彰化縣', '16', '2023-04-19 16:00', 'μg/m3'],
#   ['彰化', '彰化縣', '14', '2023-04-19 16:00', 'μg/m3'],
#   ['西屯', '臺中市', '14', '2023-04-19 16:00', 'μg/m3'],
#   ['忠明', '臺中市', '16', '2023-04-19 16:00', 'μg/m3'],
#   ['大里', '臺中市', '12', '2023-04-19 16:00', 'μg/m3'],
#   ['沙鹿', '臺中市', '14', '2023-04-19 16:00', 'μg/m3'],
#   ['豐原', '臺中市', '17', '2023-04-19 16:00', 'μg/m3'],
#   ['三義', '苗栗縣', '12', '2023-04-19 16:00', 'μg/m3'],
#   ['苗栗', '苗栗縣', '11', '2023-04-19 16:00', 'μg/m3'],
#   ['頭份', '苗栗縣', '10', '2023-04-19 16:00', 'μg/m3'],
#   ['新竹', '新竹市', '9', '2023-04-19 16:00', 'μg/m3'],
#   ['竹東', '新竹縣', '6', '2023-04-19 16:00', 'μg/m3'],
#   ['湖口', '新竹縣', '9', '2023-04-19 16:00', 'μg/m3'],
#   ['龍潭', '桃園市', '3', '2023-04-19 16:00', 'μg/m3'],
#   ['平鎮', '桃園市', '4', '2023-04-19 16:00', 'μg/m3'],
#   ['觀音', '桃園市', '9', '2023-04-19 16:00', 'μg/m3'],
#   ['大園', '桃園市', '6', '2023-04-19 16:00', 'μg/m3'],
#   ['桃園', '桃園市', '', '2023-04-19 16:00', 'μg/m3'],
#   ['大同', '臺北市', '12', '2023-04-19 16:00', 'μg/m3'],
#   ['松山', '臺北市', '7', '2023-04-19 16:00', 'μg/m3'],
#   ['古亭', '臺北市', '8', '2023-04-19 16:00', 'μg/m3'],
#   ['萬華', '臺北市', '7', '2023-04-19 16:00', 'μg/m3'],
#   ['中山', '臺北市', '11', '2023-04-19 16:00', 'μg/m3'],
#   ['士林', '臺北市', '16', '2023-04-19 16:00', 'μg/m3'],
#   ['淡水', '新北市', '7', '2023-04-19 16:00', 'μg/m3'],
#   ['林口', '新北市', '6', '2023-04-19 16:00', 'μg/m3'],
#   ['菜寮', '新北市', '10', '2023-04-19 16:00', 'μg/m3'],
#   ['新莊', '新北市', '8', '2023-04-19 16:00', 'μg/m3'],
#   ['板橋', '新北市', '10', '2023-04-19 16:00', 'μg/m3'],
#   ['土城', '新北市', '3', '2023-04-19 16:00', 'μg/m3'],
#   ['新店', '新北市', '9', '2023-04-19 16:00', 'μg/m3'],
#   ['萬里', '新北市', '12', '2023-04-19 16:00', 'μg/m3'],
#   ['汐止', '新北市', '13', '2023-04-19 16:00', 'μg/m3'],
#   ['基隆', '基隆市', '', '2023-04-19 16:00', 'μg/m3']])
